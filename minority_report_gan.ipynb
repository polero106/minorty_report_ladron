# %% [markdown]
# # Minority Report: Graph-GAN \n## Persona 1: Datos y Neo4j\n\nEste notebook implementa la conexión entre Neo4j y PyTorch Geometric usando HeteroData.

# %%
import torch\nfrom neo4j_data_utils import Neo4jHeteroConnector\n\n# Configuración\nNEO4J_URI = "bolt://localhost:7687"\nNEO4J_USER = "neo4j"\nNEO4J_PASSWORD = "password" # Cambia esto\n\nconnector = Neo4jHeteroConnector(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)\n\nprint("Conector inicializado.")

# %% [markdown]
# ### 1. Carga de Datos Heterogéneos

# %%
hetero_data = connector.fetch_hetero_data()\nprint(hetero_data)
